# %%
pip install git+https://github.com/TCDSolar/stixpy.git
# Out:
# ...
#   Cloning https://github.com/TCDSolar/stixpy.git to C:\Users\dearb\AppData\Local\Temp\pip-req-build-h7yhavdm
#   Resolved https://github.com/TCDSolar/stixpy.git to commit 5275652e577c93df341c083e9a4491578c6b3957
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for stixpy: filename=stixpy-0.3.1.dev5+g5275652e5-py3-none-any.whl size=964918 sha256=c95afbc996f8a6efefc2444caf3cf14b273a9e28a3d2841a6a57568a08c4751a
#   Stored in directory: C:\Users\dearb\AppData\Local\Temp\pip-ephem-wheel-cache-ta7cqkx6\wheels\97\79\60\a6fbd832dd79b54ab6d74a531b963ac4d4636723d7a464854a
# Successfully built stixpy
# ...
#
#    ---------- ----------------------------- 1/4 [roentgen]
# ...

# %%
pip install git
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement git (from versions: none)
# ERROR: No matching distribution found for git
